# %% [markdown]
# <a href="https://colab.research.google.com/github/Israt1063/3.Brain-Tumor-Detection-Using-Custom-CNN/blob/main/3_Brain_Tumor_Detection_Using_Custom_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Summary
#
# Step 1: Import
# Step 2: Dataset class
# Step 3: Transforms
# Step 4: DataLoaders
# Step 5: CNN model
# Step 6: Training loop
# Step 7: Run training

# %%
from google.colab import drive
drive.mount('/content/drive')

# Copy kaggle.json to right place
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# Mounted at /content/drive

# %%
# !kaggle datasets download -d navoneel/brain-mri-images-for-brain-tumor-detection
# Out:
# Dataset URL: https://www.kaggle.com/datasets/navoneel/brain-mri-images-for-brain-tumor-detection
# License(s): copyright-authors
# Downloading brain-mri-images-for-brain-tumor-detection.zip to /content
#   0% 0.00/15.1M [00:00<?, ?B/s]
# 100% 15.1M/15.1M [00:00<00:00, 823MB/s]

# %%
# !unzip brain-mri-images-for-brain-tumor-detection.zip -d brain_tumor_data
# Out:
# Archive:  brain-mri-images-for-brain-tumor-detection.zip
#   inflating: brain_tumor_data/brain_tumor_dataset/no/1 no.jpeg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/10 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/11 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/12 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/13 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/14 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/15 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/17 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/18 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/19 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/2 no.jpeg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/20 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/21 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/22 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/23 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/24 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/25 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/26 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/27 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/28 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/29 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/3 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/30 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/31 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/32 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/33 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/34 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/35 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/36 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/37 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/38 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/39 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/4 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/40 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/41 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/42 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/43 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/44no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/45 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/46 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/47 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/48 no.jpeg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/49 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/5 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/50 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/6 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/7 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/8 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/9 no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N1.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N11.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N15.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N16.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N17.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N19.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N2.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N20.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N21.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N22.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N26.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N3.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N5.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/N6.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No11.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No12.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No13.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No14.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No15.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No16.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No17.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No18.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No19.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No20.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No21.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/No22.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 1.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 10.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 100.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 2.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 3.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 4.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 5.jpeg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 6.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 7.jpeg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 8.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 89.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 9.png
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 90.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 91.jpeg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 92.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 923.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 94.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 95.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 96.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 97.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 98.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no 99.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/no/no.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y1.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y10.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y100.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y101.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y102.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y103.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y104.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y105.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y106.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y107.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y108.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y109.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y11.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y111.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y112.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y113.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y114.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y115.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y116.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y117.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y12.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y120.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y13.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y14.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y146.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y147.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y148.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y15.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y153.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y154.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y155.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y156.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y157.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y158.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y159.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y16.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y160.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y161.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y162.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y163.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y164.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y165.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y166.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y167.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y168.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y169.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y17.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y170.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y18.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y180.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y181.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y182.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y183.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y184.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y185.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y186.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y187.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y188.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y19.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y192.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y193.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y194.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y195.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y2.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y20.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y21.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y22.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y23.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y24.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y242.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y243.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y244.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y245.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y246.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y247.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y248.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y249.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y25.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y250.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y251.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y252.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y253.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y254.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y255.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y256.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y257.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y258.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y259.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y26.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y27.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y28.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y29.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y3.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y30.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y31.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y32.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y33.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y34.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y35.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y36.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y37.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y38.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y39.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y4.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y40.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y41.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y42.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y44.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y45.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y46.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y47.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y49.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y50.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y51.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y52.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y53.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y54.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y55.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y56.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y58.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y59.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y6.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y60.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y61.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y62.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y65.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y66.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y67.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y69.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y7.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y70.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y71.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y73.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y74.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y75.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y76.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y77.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y78.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y79.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y8.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y81.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y82.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y85.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y86.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y89.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y9.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y90.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y91.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y92.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y92.png
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y95.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y96.jpg
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/Y97.JPG
#   inflating: brain_tumor_data/brain_tumor_dataset/yes/
#   inflating: brain_tumor_data/yes/Y34.jpg
#   inflating: brain_tumor_data/yes/Y35.jpg
#   inflating: brain_tumor_data/yes/Y36.JPG
#   inflating: brain_tumor_data/yes/Y37.jpg
#   inflating: brain_tumor_data/yes/Y38.jpg
#   inflating: brain_tumor_data/yes/Y39.jpg
#   inflating: brain_tumor_data/yes/Y4.jpg
#   inflating: brain_tumor_data/yes/Y40.JPG
#   inflating: brain_tumor_data/yes/Y41.jpg
#   inflating: brain_tumor_data/yes/Y42.jpg
#   inflating: brain_tumor_data/yes/Y44.JPG
#   inflating: brain_tumor_data/yes/Y45.JPG
#   inflating: brain_tumor_data/yes/Y46.jpg
#   inflating: brain_tumor_data/yes/Y47.JPG
#   inflating: brain_tumor_data/yes/Y49.JPG
#   inflating: brain_tumor_data/yes/Y50.JPG
#   inflating: brain_tumor_data/yes/Y51.jpg
#   inflating: brain_tumor_data/yes/Y52.jpg
#   inflating: brain_tumor_data/yes/Y53.jpg
#   inflating: brain_tumor_data/yes/Y54.jpg
#   inflating: brain_tumor_data/yes/Y55.jpg
#   inflating: brain_tumor_data/yes/Y56.jpg
#   inflating: brain_tumor_data/yes/Y58.JPG
#   inflating: brain_tumor_data/yes/Y59.JPG
#   inflating: brain_tumor_data/yes/Y6.jpg
#   inflating: brain_tumor_data/yes/Y60.jpg
#   inflating: brain_tumor_data/yes/Y61.jpg
#   inflating: brain_tumor_data/yes/Y62.jpg
#   inflating: brain_tumor_data/yes/Y65.JPG
#   inflating: brain_tumor_data/yes/Y66.JPG
#   inflating: brain_tumor_data/yes/Y67.JPG
#   inflating: brain_tumor_data/yes/Y69.jpg
#   inflating: brain_tumor_data/yes/Y7.jpg
#   inflating: brain_tumor_data/yes/Y70.jpg
#   inflating: brain_tumor_data/yes/Y71.JPG
#   inflating: brain_tumor_data/yes/Y73.jpg
#   inflating: brain_tumor_data/yes/Y74.jpg
#   inflating: brain_tumor_data/yes/Y75.JPG
#   inflating: brain_tumor_data/yes/Y76.jpg
#   inflating: brain_tumor_data/yes/Y77.jpg
#   inflating: brain_tumor_data/yes/Y78.jpg
#   inflating: brain_tumor_data/yes/Y79.jpg
#   inflating: brain_tumor_data/yes/Y8.jpg
#   inflating: brain_tumor_data/yes/Y81.jpg
#   inflating: brain_tumor_data/yes/Y82.jpg
#   inflating: brain_tumor_data/yes/Y85.JPG
#   inflating: brain_tumor_data/yes/Y86.JPG
#   inflating: brain_tumor_data/yes/Y89.JPG
#   inflating: brain_tumor_data/yes/Y9.jpg
#   inflating: brain_tumor_data/yes/Y90.jpg
#   inflating: brain_tumor_data/yes/Y91.jpg
#   inflating: brain_tumor_data/yes/Y92.jpg
#   inflating: brain_tumor_data/yes/Y92.png
#   inflating: brain_tumor_data/yes/Y95.jpg
#   inflating: brain_tumor_data/yes/Y96.jpg
#   inflating: brain_tumor_data/yes/Y97.JPG
#   inflating: brain_tumor_data/yes/Y98.JPG
#   inflating: brain_tumor_data/yes/Y99.JPG

# %%
import os
print(os.listdir("brain_tumor_data"))
# Out:
# ['yes', 'no', 'brain_tumor_dataset']

# %%
#Step 1: Import necessary libraries
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image

# %%
class BrainTumorDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = sorted(os.listdir(root_dir))  # ['no', 'yes']
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}

        self.samples = []
        for cls in self.classes:
            cls_folder = os.path.join(root_dir, cls)
            for fname in os.listdir(cls_folder):
                path = os.path.join(cls_folder, fname)
                self.samples.append((path, self.class_to_idx[cls]))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
train_transforms = transforms.Compose([
    transforms.Resize((128,128)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],  # ImageNet means, can change if needed
                         std=[0.229, 0.224, 0.225])
])

val_transforms = transforms.Compose([
    transforms.Resize((128,128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
dataset_root = "brain_tumor_data/brain_tumor_dataset"

train_dataset = BrainTumorDataset(dataset_root, transform=train_transforms)
val_dataset = BrainTumorDataset(dataset_root, transform=val_transforms)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)

# %%
class BrainTumorCNN(nn.Module):
    def __init__(self, num_classes=2):
        super(BrainTumorCNN, self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),  # Input channels 3 for RGB
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # 128x128 -> 64x64

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # 64x64 -> 32x32

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # 32x32 -> 16x16
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128 * 16 * 16, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
def train_classifier(model, train_loader, val_loader, epochs, device):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        avg_train_loss = train_loss / len(train_loader)

        model.eval()
        val_loss = 0
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                _, preds = torch.max(outputs, 1)
                correct += (preds == labels).sum().item()
                total += labels.size(0)

        avg_val_loss = val_loss / len(val_loader)
        val_acc = 100 * correct / total

        print(f"Epoch {epoch+1}/{epochs} - "
              f"Train Loss: {avg_train_loss:.4f} - "
              f"Val Loss: {avg_val_loss:.4f} - "
              f"Val Accuracy: {val_acc:.2f}%")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = BrainTumorCNN(num_classes=2)

train_classifier(model, train_loader, val_loader, epochs=10, device=device)
# Out:
# Epoch 1/10 - Train Loss: 0.9845 - Val Loss: 0.6934 - Val Accuracy: 45.85%
# Epoch 2/10 - Train Loss: 0.6749 - Val Loss: 0.6147 - Val Accuracy: 72.33%
# Epoch 3/10 - Train Loss: 0.6170 - Val Loss: 0.5620 - Val Accuracy: 71.54%
# Epoch 4/10 - Train Loss: 0.5631 - Val Loss: 0.5305 - Val Accuracy: 73.12%
# Epoch 5/10 - Train Loss: 0.5273 - Val Loss: 0.4719 - Val Accuracy: 80.63%
# Epoch 6/10 - Train Loss: 0.4921 - Val Loss: 0.4384 - Val Accuracy: 81.03%
# Epoch 7/10 - Train Loss: 0.4865 - Val Loss: 0.4640 - Val Accuracy: 82.21%
# Epoch 8/10 - Train Loss: 0.4402 - Val Loss: 0.4017 - Val Accuracy: 81.42%
# Epoch 9/10 - Train Loss: 0.4359 - Val Loss: 0.3901 - Val Accuracy: 82.21%
# Epoch 10/10 - Train Loss: 0.4101 - Val Loss: 0.3523 - Val Accuracy: 84.58%

# %%
epoch_accuracies = [45.85, 72.33, 71.54, 73.12, 80.63, 81.03, 82.21, 81.42, 82.21, 84.58]
average_accuracy = sum(epoch_accuracies) / len(epoch_accuracies)
print(f"Average validation accuracy over 10 epochs: {average_accuracy:.2f}%")
# Out:
# Average validation accuracy over 10 epochs: 75.49%

# %%
torch.save(model.state_dict(), "brain_tumor_cnn.pth")

# %%
model = BrainTumorCNN(num_classes=2)
model.load_state_dict(torch.load("brain_tumor_cnn.pth"))
model.eval()
# Out:
# BrainTumorCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=32768, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=2, bias=True)
#   )
# )
